# %%
import pandas as pd
#from mlxtend.frequent_patterns import association_rules
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
import plotly.express as px
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Data/Assignment-1_Data.csv")
# Out:
# C:\Users\Yehia\AppData\Local\Temp\ipykernel_10196\1539581619.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("Data/Assignment-1_Data.csv")

# %%
df.head()
# Out:
#    BillNo                             Itemname  Quantity            Date  \
# 0  536365   WHITE HANGING HEART T-LIGHT HOLDER         6  12/1/2010 8:26
# 1  536365                  WHITE METAL LANTERN         6  12/1/2010 8:26
# 2  536365       CREAM CUPID HEARTS COAT HANGER         8  12/1/2010 8:26
# 3  536365  KNITTED UNION FLAG HOT WATER BOTTLE         6  12/1/2010 8:26
# 4  536365       RED WOOLLY HOTTIE WHITE HEART.         6  12/1/2010 8:26
#
#    Price  CustomerID         Country
# 0   2.55     17850.0  United Kingdom
# 1   3.39     17850.0  United Kingdom
# 2   2.75     17850.0  United Kingdom
# 3   3.39     17850.0  United Kingdom
# 4   3.39     17850.0  United Kingdom

# %%
df.Country.value_counts()
# Out:
# United Kingdom          487622
# Germany                   9042
# France                    8408
# Spain                     2485
# Netherlands               2363
# Belgium                   2031
# Switzerland               1967
# Portugal                  1501
# Australia                 1185
# Norway                    1072
# Italy                      758
# Sweden                     451
# Unspecified                446
# Austria                    398
# Poland                     330
# Japan                      321
# Israel                     295
# Hong Kong                  284
# Singapore                  222
# Iceland                    182
# USA                        179
# Greece                     145
# Malta                      112
# United Arab Emirates        68
# RSA                         58
# Lebanon                     45
# Lithuania                   35
# Brazil                      32
# Bahrain                     18
# Saudi Arabia                 9
# Name: Country, dtype: int64

# %%
df= df[df.Country=="Germany"]
df["Itemname"]=df["Itemname"].str.strip()
df.dropna(inplace=True)

# %%
df.head()
# Out:
#       BillNo                             Itemname  Quantity             Date  \
# 1099  536527              SET OF 6 T-LIGHTS SANTA         6  12/1/2010 13:04
# 1100  536527  ROTATING SILVER ANGELS T-LIGHT HLDR         6  12/1/2010 13:04
# 1101  536527   MULTI COLOUR SILVER T-LIGHT HOLDER        12  12/1/2010 13:04
# 1102  536527        5 HOOK HANGER MAGIC TOADSTOOL        12  12/1/2010 13:04
# 1103  536527           3 HOOK HANGER MAGIC GARDEN        12  12/1/2010 13:04
#
#       Price  CustomerID  Country
# 1099   2.95     12662.0  Germany
# 1100   2.55     12662.0  Germany
# 1101   0.85     12662.0  Germany
# 1102   1.65     12662.0  Germany
# 1103   1.95     12662.0  Germany

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9042 entries, 1099 to 521960
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   BillNo      9042 non-null   object
#  1   Itemname    9042 non-null   object
#  2   Quantity    9042 non-null   int64
#  3   Date        9042 non-null   object
#  4   Price       9042 non-null   float64
#  5   CustomerID  9042 non-null   float64
#  6   Country     9042 non-null   object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 565.1+ KB

# %%
basket=df.groupby(['BillNo', 'Itemname'])['Quantity'].sum().unstack().reset_index().fillna(0).set_index('BillNo')

# %%
basket.drop(columns="POSTAGE",inplace=True)

# %%
basket.head()
# Out:
# Itemname  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# BillNo
# 536527                       0.0                         0.0
# 536840                       0.0                         0.0
# 536861                       0.0                         0.0
# 536967                       0.0                         0.0
# 536983                       0.0                         0.0
#
# Itemname  12 IVORY ROSE PEG PLACE SETTINGS  12 MESSAGE CARDS WITH ENVELOPES  \
# BillNo
# 536527                                 0.0                              0.0
# 536840                                 0.0                              0.0
# 536861                                 0.0                              0.0
# 536967                                 0.0                              0.0
# 536983                                 0.0                              0.0
#
# Itemname  12 PENCIL SMALL TUBE WOODLAND  12 PENCILS SMALL TUBE RED RETROSPOT  \
# BillNo
# 536527                              0.0                                  0.0
# 536840                              0.0                                  0.0
# 536861                              0.0                                  0.0
# 536967                              0.0                                  0.0
# 536983                              0.0                                  0.0
#
# Itemname  12 PENCILS SMALL TUBE SKULL  12 PENCILS TALL TUBE POSY  \
# BillNo
# 536527                            0.0                        0.0
# 536840                            0.0                        0.0
# 536861                            0.0                        0.0
# 536967                            0.0                        0.0
# 536983                            0.0                        0.0
#
# Itemname  12 PENCILS TALL TUBE RED RETROSPOT  12 PENCILS TALL TUBE SKULLS  \
# BillNo
# 536527                                   0.0                          0.0
# 536840                                   0.0                          0.0
# 536861                                   0.0                          0.0
# 536967                                   0.0                          0.0
# 536983                                   0.0                          0.0
#
# Itemname  ...  YULETIDE IMAGES GIFT WRAP SET  ZINC  HEART T-LIGHT HOLDER  \
# BillNo    ...
# 536527    ...                            0.0                         0.0
# 536840    ...                            0.0                         0.0
# 536861    ...                            0.0                         0.0
# 536967    ...                            0.0                         0.0
# 536983    ...                            0.0                         0.0
#
# Itemname  ZINC  STAR T-LIGHT HOLDER  ZINC BOX SIGN HOME  \
# BillNo
# 536527                          0.0                 0.0
# 536840                          0.0                 0.0
# 536861                          0.0                 0.0
# 536967                          0.0                 0.0
# 536983                          0.0                 0.0
#
# Itemname  ZINC FOLKART SLEIGH BELLS  ZINC HEART LATTICE T-LIGHT HOLDER  \
# BillNo
# 536527                          0.0                                0.0
# 536840                          0.0                                0.0
# 536861                          0.0                                0.0
# 536967                          0.0                                0.0
# 536983                          0.0                                0.0
#
# Itemname  ZINC METAL HEART DECORATION  ZINC T-LIGHT HOLDER STAR LARGE  \
# BillNo
# 536527                            0.0                             0.0
# 536840                            0.0                             0.0
# 536861                            0.0                             0.0
# 536967                            0.0                             0.0
# 536983                            0.0                             0.0
#
# Itemname  ZINC T-LIGHT HOLDER STARS SMALL  ZINC WILLIE WINKIE  CANDLE STICK
# BillNo
# 536527                                0.0                               0.0
# 536840                                0.0                               0.0
# 536861                                0.0                               0.0
# 536967                                0.0                               0.0
# 536983                                0.0                               0.0
#
# [5 rows x 1694 columns]

# %%
basket.shape
# Out:
# (457, 1694)

# %%
#below function converts a values < 0 to 0 and value greater than equal 1 to 1.  
def encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1
#apply function to data using applymap.
basket_sets = basket.applymap(encode_units)

# %%
frequent_itemsets = apriori(basket_sets, min_support=0.07, use_colnames=True)
# Out:
# C:\Users\Yehia\anaconda3\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:110: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(

# %%
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)

# %%
rules.head()
# Out:
#                             antecedents                           consequents  \
# 0  (ROUND SNACK BOXES SET OF4 WOODLAND)    (PLASTERS IN TIN WOODLAND ANIMALS)
# 1    (PLASTERS IN TIN WOODLAND ANIMALS)  (ROUND SNACK BOXES SET OF4 WOODLAND)
# 2  (ROUND SNACK BOXES SET OF4 WOODLAND)   (ROUND SNACK BOXES SET OF 4 FRUITS)
# 3   (ROUND SNACK BOXES SET OF 4 FRUITS)  (ROUND SNACK BOXES SET OF4 WOODLAND)
# 4  (ROUND SNACK BOXES SET OF4 WOODLAND)                  (SPACEBOY LUNCH BOX)
#
#    antecedent support  consequent support   support  confidence      lift  \
# 0            0.245077            0.137856  0.074398    0.303571  2.202098
# 1            0.137856            0.245077  0.074398    0.539683  2.202098
# 2            0.245077            0.157549  0.131291    0.535714  3.400298
# 3            0.157549            0.245077  0.131291    0.833333  3.400298
# 4            0.245077            0.102845  0.070022    0.285714  2.778116
#
#    leverage  conviction  zhangs_metric
# 0  0.040613    1.237951       0.723103
# 1  0.040613    1.640006       0.633174
# 2  0.092679    1.814509       0.935072
# 3  0.092679    4.529540       0.837922
# 4  0.044817    1.256018       0.847826
